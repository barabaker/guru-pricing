# %% [markdown]
# ### Кому мы должны отдать книгу из приведенных ниже студентов согласно данной логике, если сегодня 10.03.24 и никто из студентов еще не начал пользоваться данной книгой:
#
#  - Иван - подал заявку 1.03.24
#  - Мария - подала заявку 5.03.24
#  - Петр - подал заявку 9.03.2024
# ***
# Представим, что вы студент и хотите взять книгу для получения знаний по предмету -Вы оставляете заявку в библиотеку и вы были первым. При такой картине вы в течении 7 дней имеете право начать пользоваться этой книгой а)при условии, что в течение 7 дней вы НАЧАЛИ пользоваться книгой, то в течении 20 дней эта книга ваша и остальные заявки будут автоматически аннулированы б)при условии, что в течение 7 дней вы НЕ НАЧАЛИ пользоваться книгой, то первой же заявке после истечении этого времени будет одобрено право пользования книгой для получения знаний NB: при условии, что после вашей заявки и истечении 7 дней ни 1 другой студент не изъявил желание пользоваться данной книгой, то в таком случае вы можете начать ей пользоваться в любой удобный момент, главное чтобы не было других заявок на использование данной книги, иначе знания будет получать уже студен, оставивший заявку

# %% [markdown]
# ## Давайте проанализируем условия и решим, кто получит книгу:
#
# 1. Иван подал заявку 1.03.24
#    - У него есть 7 дней (до 8.03.24) для начала использования книги
#    - На момент 10.03.24 он еще может начать пользоваться книгой
#
# 2. Мария подала заявку 5.03.24
#    - Ее заявка придет в силу только после Ивана
#    - Если Иван не начнет использовать книгу до 8.03.24, она получит право на книгу
#
# 3. Петр подал заявку 9.03.2024
#    - Его заявка последняя по времени
#
# ### На момент 10.03.24 книга ДОЛЖНА БЫТЬ ОТДАНА ИВАНУ, так как:
# - Он первый подал заявку
# - У него еще есть время (до 8.03.24) начать пользоваться книгой
# - Если он не начнет пользоваться до 8.03.24, право перейдет к Марии
#
# ### Книга должна быть предоставлена Ивану.
